# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdunabiRamadan/CIS310-Python-for-Data-Analysis-2nd-Edition-book/blob/1st-edition/ch22/numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ramadan Abdunabi
# ## 08/27/2020
# ### Python - Practice Numbers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
sample_words = [
    "This", "is", "a", "sample", "string", "with", "fifteen", "words",
    "that", "demonstrates", "the", "creation", "of", "text", "data."
]
sample_string = " ".join(sample_words)
print(sample_string)
# Out:
# This is a sample string with fifteen words that demonstrates the creation of text data.

# %%
another_sample_words = [
    "This", "is", "another", "sample", "string", "with", "fourteen", "words",
    "for", "demonstration", "purposes", "only", "and", "testing."
]
another_sample_string = " ".join(another_sample_words)
print(another_sample_string)
# Out:
# This is another sample string with fourteen words for demonstration purposes only and testing.

# %%
another_sample_string
# Out:
# 'This is another sample string with fourteen words for demonstration purposes only and testing.'

# %%
# !git clone "https://github.com/AbdunabiRamadan/CIS310-Python-for-Data-Analysis-2nd-Edition-book.git"
# Out:
# Cloning into 'CIS310-Python-for-Data-Analysis-2nd-Edition-book'...
# remote: Enumerating objects: 443, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 443 (delta 5), reused 0 (delta 0), pack-reused 432 (from 2)
# Receiving objects: 100% (443/443), 40.55 MiB | 7.20 MiB/s, done.
# Resolving deltas: 100% (137/137), done.
# Updating files: 100% (211/211), done.

# %%
cd /content/CIS310-Python-for-Data-Analysis-2nd-Edition-book
# Out:
# /content/CIS310-Python-for-Data-Analysis-2nd-Edition-book

# %%
ls
# Out:
# appa.ipynb  ch05.ipynb  ch09.ipynb  ch13.ipynb  examples/
# ch02.ipynb  ch06.ipynb  ch10.ipynb  ch14.ipynb  README.md
# ch03.ipynb  ch07.ipynb  ch11.ipynb  COPYING     requirements.txt
# ch04.ipynb  ch08.ipynb  ch12.ipynb  datasets/   test.ipynb

# %%
from pathlib import PureWindowsPath
PureWindowsPath
# Out:
# pathlib.PureWindowsPath

# %%
pwd
# Out:
# '/content/CIS310-Python-for-Data-Analysis-2nd-Edition-book'

# %%
5 % 2
# Out:
# 1

# %%
4 ** 4
# Out:
# 256

# %%
4 + 2 * 2 + 1
# Out:
# 9

# %%
(4 + 2) * (2 + 1)
# Out:
# 18

# %%
x = 10

# %%
x
# Out:
# 10

# %%
x = x * 2

# %%
x
# Out:
# 20

# %%
x / 10
# Out:
# 2.0

# %%
x
# Out:
# 20

# %%
y = x / 2

# %%
y
# Out:
# 10.0

# %%
age = 20

# %%
age
# Out:
# 20

# %%
area = 4.5

# %%
area
# Out:
# 4.5

# %%
average = 3.5

# %%
average
# Out:
# 3.5

# %%
# Floor-divide
a = 7
b = 2

# %%
a
# Out:
# 7

# %%
b
# Out:
# 2

# %%
a // b
# Out:
# 3

# %%
num_hours = 10

pay_rate = 9.88

total_pay = num_hours * pay_rate

# %%
total_pay
# Out:
# 98.80000000000001

# %%
# print a statement
print('Hello, World!')
# Out:
# Hello, World!

# %%
type(1)
# Out:
# int

# %%
type(1.5)
# Out:
# float

# %%
z = 5

# %%
z
# Out:
# 5

# %%
'''
Introspection
Using a question mark (?) before or after a variable will display some general information
about the object:
'''
z?

# %%
lst = [1, 2, 3]

# %%
lst
# Out:
# [1, 2, 3]

# %%
lst?

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
# Tab Completion
an_apple = 27
an_example = 42

# %%
an_example
# Out:
# 42

# %%
x = True

# %%
x
# Out:
# True
