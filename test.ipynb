# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdunabiRamadan/CIS310-Python-for-Data-Analysis-2nd-Edition-book/blob/2nd-edition/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy

# %%
import pandas as pd
